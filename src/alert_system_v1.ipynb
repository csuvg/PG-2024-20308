# %% [markdown]
# # Sistema de asistencia de manejo de un vehículo terrestre a través de visión por computadora V1

# %%
import time
import sys
import random
import cv2
import os
from datetime import datetime
from ultralytics import YOLO  # Para cargar el modelo YOLOv8

# %% [markdown]
# Cargar las rutas de los otros modulos del sistema

# %%
sys.path.append('sensores_input')  # Agregar la ruta del simulador de sensores
sys.path.append('Traffic_Signs_Model')  # Agregar la ruta del modelo YOLOv8

# %% [markdown]
# Cargar simulacion de sensores

# %%
from simulacionSensores import simulate_speed  # Importar simulador de velocidad

# %% [markdown]
# Cargar el modelo YOLOv8 entrenado

# %%
model = YOLO('Traffic_Signs_Model/traffic_signs_model.pt')

# %%
print(model.names)
# Out:
# {0: 'pedestrian_traffic_light_green', 1: 'pedestrian_traffic_light_red', 2: 'traffic_light_green', 3: 'traffic_light_red', 4: 'traffic_light_yellow', 5: 'stop'}

# %% [markdown]
# Definiciones generales de limites de velocidad y objetos peligrosos

# %%
SPEED_LIMIT = 80  # Límite de velocidad urbana (km/h)
DANGER_OBJECTS = ['stop', 'traffic_light_red', 'pedestrian_traffic_light_red']  # Objetos que generan alerta

# %% [markdown]
# Hacemos un archivo con logs para poder medir y saber como funciona nuestro modelo en su prueba en un entorno simulado

# %%
log_filename = 'modelv1_alert_log.txt'
with open(log_filename, 'w') as log_file:
    log_file.write("Alerta Log para ModelV1\n")
    log_file.write("Fecha de creación: " + datetime.now().strftime("%Y-%m-%d %H:%M:%S") + "\n\n")

# %% [markdown]
# Función para la generación de alertas

# %%
def generate_alert(object_detected, current_speed):
    if object_detected in DANGER_OBJECTS and current_speed > 0:
        return f"ALERTA: {object_detected}"
    return "No hay alerta."

# %% [markdown]
# Función para la detección de objetos frame a frame usando el modelo de YOLOv8

# %%
# Función para la detección de objetos frame a frame usando YOLOv8
def detect_objects(frame):
    results = model(frame)  # Pasamos el frame al modelo YOLO
    if results and len(results[0].boxes) > 0:
        # Convertir el tensor de la clase a un entero para poder usarlo como índice
        top_object_idx = int(results[0].boxes[0].cls.item())
        top_object = results[0].names[top_object_idx]
        return top_object
    else:
        return "No objects detected"

# %% [markdown]
# Procesar distintos tipos de input

# %%
def process_input(input_type, input_source, frame_rate=20):
    cap = None
    if input_type == 'image':
        # Cargar la imagen directamente
        frame = cv2.imread(input_source)
        yield frame, 0  # Se devuelve un timestamp de 0 ya que es una imagen estática

    elif input_type == 'video':
        cap = cv2.VideoCapture(input_source)

    elif input_type == 'camera':
        cap = cv2.VideoCapture(0)  # 0 para la cámara predeterminada

    # Si es un video o la cámara
    if cap:
        current_frame = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break  # Salir si no hay más frames o no se puede leer

            timestamp = cap.get(cv2.CAP_PROP_POS_MSEC)  # Obtener el timestamp en milisegundos

            if input_type == 'video' and current_frame % frame_rate == 0:
                yield frame, timestamp  # Devolver frame y timestamp cada 'frame_rate'

            elif input_type == 'camera':
                yield frame, timestamp  # Devolver frame en tiempo real si es la cámara

            current_frame += 1

        cap.release()

# %% [markdown]
# Funcionamiento del modelo en su versión 1

# %%
def modelv1(input_type='camera', input_source=None):
    # Inicializar parámetros de simulación de velocidad
    current_speed = 0  # Velocidad inicial del vehículo
    max_speed = 70
    acceleration = 5.0
    deceleration = 7.0
    stop_deceleration = 15.0
    time_between_stops = 7
    stop_chance = 0.1

    # Iterar sobre los frames según el input type
    for frame, timestamp in process_input(input_type, input_source):
        # Simular velocidad
        current_speed = simulate_speed(current_speed, max_speed, acceleration, deceleration, stop_deceleration, time_between_stops, stop_chance)
        # current_speed = 60
        print(f"Velocidad actual: {current_speed} km/h")

        # Mostrar el frame en una ventana
        cv2.imshow("Frame", frame)

        # Procesar detección de objetos
        detected_object = detect_objects(frame)
        print(f"Objeto detectado: {detected_object}")

        # Generar alerta
        alert_message = generate_alert(detected_object, current_speed)
        print(alert_message)

        # Guardar los datos en el archivo de log si hay una alerta
        if "ALERTA" in alert_message:
            with open(log_filename, 'a') as log_file:
                log_file.write(f"Timestamp: {timestamp} ms\n")
                log_file.write(f"Velocidad: {current_speed} km/h\n")
                log_file.write(f"Objeto detectado: {detected_object}\n")
                log_file.write(f"Mensaje de alerta: {alert_message}\n")
                log_file.write(f"-----------------------------\n")

        # Romper el ciclo si se presiona la tecla 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        # Simulación de intervalo de tiempo de 0.1 segundos
        time.sleep(0.1)

    cv2.destroyAllWindows()

# %%
input_type = 'video'  # Cambiar entre 'image', 'video', 'camera' según sea necesario
input_source = 'video_input/Recorriendo CIUDAD DE GUATEMALA en vehículo (Parte 1) - GUATEMALA 2024.mp4'  # Ruta del archivo de video

# %%
modelv1(input_type, input_source)
# Out:
# Velocidad actual: 0.56 km/h
#
# 0: 384x640 2 traffic_light_yellows, 49.6ms
# Speed: 1.5ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 0.81 km/h
#
# 0: 384x640 2 traffic_light_greens, 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 1.2 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 1.9 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 2.08 km/h
#
# 0: 384x640 1 traffic_light_green, 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 2.54 km/h
#
# 0: 384x640 1 traffic_light_green, 42.9ms
# Speed: 0.8ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 2.97 km/h
#
# 0: 384x640 1 traffic_light_green, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 3.18 km/h
#
# 0: 384x640 2 traffic_light_greens, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 4.05 km/h
#
# 0: 384x640 2 traffic_light_greens, 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 4.41 km/h
#
# 0: 384x640 3 traffic_light_greens, 44.8ms
# Speed: 0.9ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 4.96 km/h
#
# 0: 384x640 2 traffic_light_greens, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 5.53 km/h
#
# 0: 384x640 2 traffic_light_greens, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 6.08 km/h
#
# 0: 384x640 2 traffic_light_greens, 46.2ms
# Speed: 0.9ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 6.6 km/h
#
# 0: 384x640 1 traffic_light_green, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 7.0 km/h
#
# 0: 384x640 3 traffic_light_greens, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 7.32 km/h
#
# 0: 384x640 2 traffic_light_greens, 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 7.53 km/h
#
# 0: 384x640 1 traffic_light_green, 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 8.35 km/h
#
# 0: 384x640 1 traffic_light_green, 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 8.65 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.06 km/h
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 9.17 km/h
#
# 0: 384x640 1 traffic_light_green, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.54 km/h
#
# 0: 384x640 1 traffic_light_green, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.59 km/h
#
# 0: 384x640 1 traffic_light_green, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.65 km/h
#
# 0: 384x640 1 traffic_light_green, 73.1ms
# Speed: 0.8ms preprocess, 73.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 10.43 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 10.81 km/h
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 11.4 km/h
#
# 0: 384x640 2 traffic_light_greens, 48.8ms
# Speed: 0.8ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 12.07 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.5ms
# Speed: 0.9ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 13.0 km/h
#
# 0: 384x640 2 traffic_light_greens, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 13.27 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 14.11 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 14.42 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 14.95 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 42.1ms
# Speed: 0.8ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 15.81 km/h
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 16.24 km/h
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 16.97 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 17.64 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 17.97 km/h
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 18.5 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.7ms
# Speed: 0.8ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 18.55 km/h
#
# 0: 384x640 2 traffic_light_greens, 40.1ms
# Speed: 0.9ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.42 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 1 stop, 39.6ms
# Speed: 0.7ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.58 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 37.9ms
# Speed: 0.9ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 19.82 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 20.5 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 45.0ms
# Speed: 0.8ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 21.35 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 1 traffic_light_green, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 21.78 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 161.3ms
# Speed: 2.4ms preprocess, 161.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 22.09 km/h
#
# 0: 384x640 1 traffic_light_green, 118.5ms
# Speed: 1.7ms preprocess, 118.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 22.91 km/h
#
# 0: 384x640 1 traffic_light_green, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 23.08 km/h
#
# 0: 384x640 1 traffic_light_green, 52.9ms
# Speed: 0.8ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 23.71 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 47.7ms
# Speed: 0.9ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: traffic_light_red
# Velocidad actual: 24.33 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 24.79 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 25.13 km/h
#
# 0: 384x640 1 traffic_light_green, 52.7ms
# Speed: 0.8ms preprocess, 52.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 25.6 km/h
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 25.9 km/h
#
# 0: 384x640 1 traffic_light_yellow, 39.2ms
# Speed: 0.7ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 26.09 km/h
#
# 0: 384x640 1 traffic_light_green, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 26.47 km/h
#
# 0: 384x640 2 traffic_light_greens, 74.2ms
# Speed: 0.9ms preprocess, 74.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 26.82 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 26.97 km/h
#
# 0: 384x640 1 traffic_light_green, 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 27.14 km/h
#
# 0: 384x640 1 traffic_light_green, 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 27.87 km/h
#
# 0: 384x640 (no detections), 38.6ms
# Speed: 0.9ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 27.87 km/h
#
# 0: 384x640 2 traffic_light_greens, 39.1ms
# Speed: 0.7ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 28.64 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 29.5 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 34.8ms
# Speed: 0.9ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 30.29 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 35.1ms
# Speed: 0.8ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 30.53 km/h
#
# 0: 384x640 2 traffic_light_greens, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 30.73 km/h
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 31.17 km/h
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 0.8ms preprocess, 35.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 31.5 km/h
#
# 0: 384x640 1 traffic_light_green, 36.0ms
# Speed: 0.9ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 31.76 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 3 traffic_light_greens, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.03 km/h
#
# 0: 384x640 1 traffic_light_green, 36.2ms
# Speed: 0.9ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.21 km/h
#
# 0: 384x640 2 traffic_light_greens, 54.5ms
# Speed: 0.9ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.33 km/h
#
# 0: 384x640 1 traffic_light_green, 37.4ms
# Speed: 0.7ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.35 km/h
#
# 0: 384x640 1 traffic_light_green, 36.3ms
# Speed: 0.8ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.38 km/h
#
# 0: 384x640 (no detections), 36.0ms
# Speed: 0.7ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 32.81 km/h
#
# 0: 384x640 1 traffic_light_green, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 33.32 km/h
#
# 0: 384x640 1 traffic_light_green, 35.4ms
# Speed: 0.9ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 33.96 km/h
#
# 0: 384x640 2 traffic_light_greens, 38.9ms
# Speed: 0.8ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 34.15 km/h
#
# 0: 384x640 (no detections), 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 34.32 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: traffic_light_red
# Velocidad actual: 34.68 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 1 traffic_light_red, 35.9ms
# Speed: 0.8ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: traffic_light_red
# Velocidad actual: 35.38 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_red, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: traffic_light_red
# Velocidad actual: 35.92 km/h
#
# 0: 384x640 2 traffic_light_greens, 38.4ms
# Speed: 0.9ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 36.65 km/h
#
# 0: 384x640 1 traffic_light_green, 37.0ms
# Speed: 0.8ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 36.96 km/h
#
# 0: 384x640 2 traffic_light_greens, 36.7ms
# Speed: 0.9ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 37.55 km/h
#
# 0: 384x640 2 traffic_light_greens, 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 37.79 km/h
#
# 0: 384x640 1 traffic_light_green, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 38.22 km/h
#
# 0: 384x640 1 traffic_light_green, 34.8ms
# Speed: 0.8ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 38.85 km/h
#
# 0: 384x640 1 traffic_light_green, 34.7ms
# Speed: 0.7ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 39.43 km/h
#
# 0: 384x640 1 traffic_light_green, 37.9ms
# Speed: 0.9ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 39.89 km/h
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 0.9ms preprocess, 36.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 40.52 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 41.06 km/h
#
# 0: 384x640 (no detections), 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 41.87 km/h
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 0.7ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 41.87 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 42.29 km/h
#
# 0: 384x640 1 traffic_light_green, 32.0ms
# Speed: 0.8ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 42.88 km/h
#
# 0: 384x640 2 traffic_light_greens, 37.8ms
# Speed: 0.8ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 43.44 km/h
#
# 0: 384x640 2 traffic_light_greens, 37.0ms
# Speed: 0.9ms preprocess, 37.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 43.67 km/h
#
# 0: 384x640 1 traffic_light_green, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 44.23 km/h
#
# 0: 384x640 1 traffic_light_green, 34.6ms
# Speed: 0.9ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 44.79 km/h
#
# 0: 384x640 1 traffic_light_green, 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 45.79 km/h
#
# 0: 384x640 1 traffic_light_green, 36.3ms
# Speed: 1.2ms preprocess, 36.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 46.58 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 46.69 km/h
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 46.74 km/h
#
# 0: 384x640 1 traffic_light_green, 37.8ms
# Speed: 0.8ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 47.27 km/h
#
# 0: 384x640 1 traffic_light_green, 37.9ms
# Speed: 0.8ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 47.92 km/h
#
# 0: 384x640 1 traffic_light_green, 32.5ms
# Speed: 0.9ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 48.56 km/h
#
# 0: 384x640 1 traffic_light_green, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 49.36 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 49.89 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 45.4ms
# Speed: 4.6ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 49.92 km/h
#
# 0: 384x640 (no detections), 31.8ms
# Speed: 0.7ms preprocess, 31.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 50.73 km/h
#
# 0: 384x640 1 traffic_light_green, 35.6ms
# Speed: 0.7ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 51.47 km/h
#
# 0: 384x640 2 traffic_light_greens, 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 51.5 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 31.8ms
# Speed: 0.8ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 51.8 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 33.7ms
# Speed: 0.8ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 51.97 km/h
#
# 0: 384x640 1 traffic_light_green, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 52.17 km/h
#
# 0: 384x640 1 traffic_light_green, 33.7ms
# Speed: 0.9ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 52.38 km/h
#
# 0: 384x640 1 traffic_light_green, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 52.55 km/h
#
# 0: 384x640 2 traffic_light_yellows, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 52.55 km/h
#
# 0: 384x640 1 traffic_light_yellow, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 51.05 km/h
#
# 0: 384x640 2 traffic_light_yellows, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 49.55 km/h
#
# 0: 384x640 1 traffic_light_yellow, 39.2ms
# Speed: 0.9ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 48.05 km/h
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 0.9ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 46.55 km/h
#
# 0: 384x640 1 traffic_light_green, 37.8ms
# Speed: 0.8ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 45.05 km/h
#
# 0: 384x640 1 traffic_light_green, 34.4ms
# Speed: 0.8ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 43.55 km/h
#
# 0: 384x640 1 traffic_light_green, 33.3ms
# Speed: 0.8ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 42.05 km/h
#
# 0: 384x640 1 traffic_light_green, 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 40.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 36.5ms
# Speed: 0.9ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: pedestrian_traffic_light_red
# Velocidad actual: 39.05 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 37.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 37.0ms
# Speed: 0.8ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 36.05 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 43.0ms
# Speed: 0.8ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 34.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 33.05 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 39.8ms
# Speed: 0.7ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 31.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 36.8ms
# Speed: 0.9ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 3 pedestrian_traffic_light_greens, 46.5ms
# Speed: 0.9ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 28.55 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 27.05 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 25.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 24.05 km/h
#
# 0: 384x640 1 stop, 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: stop
# ALERTA: stop
# Velocidad actual: 22.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 21.05 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 1 traffic_light_green, 1 traffic_light_yellow, 35.2ms
# Speed: 0.9ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 1 traffic_light_yellow, 36.7ms
# Speed: 0.9ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 18.05 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 16.55 km/h
#
# 0: 384x640 1 traffic_light_green, 36.3ms
# Speed: 0.8ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 15.05 km/h
#
# 0: 384x640 1 traffic_light_green, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 13.55 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 2 traffic_light_greens, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 12.05 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 41.1ms
# Speed: 0.7ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 10.55 km/h
#
# 0: 384x640 1 traffic_light_green, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.05 km/h
#
# 0: 384x640 1 traffic_light_green, 36.4ms
# Speed: 0.8ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 7.55 km/h
#
# 0: 384x640 1 traffic_light_green, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 6.05 km/h
#
# 0: 384x640 1 traffic_light_yellow, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 4.55 km/h
#
# 0: 384x640 1 traffic_light_yellow, 44.2ms
# Speed: 0.8ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 3.05 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 1.55 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0.05 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 37.0ms
# Speed: 0.9ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 3 traffic_light_greens, 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_yellow, 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_yellow, 36.9ms
# Speed: 0.7ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 32.1ms
# Speed: 1.1ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 0.7ms preprocess, 41.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 35.0ms
# Speed: 0.9ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 0.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 43.7ms
# Speed: 0.8ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 36.1ms
# Speed: 0.8ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 stop, 35.1ms
# Speed: 0.8ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: stop
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_yellow, 37.6ms
# Speed: 0.8ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 35.6ms
# Speed: 0.8ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 36.8ms
# Speed: 0.7ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 36.4ms
# Speed: 0.8ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 34.7ms
# Speed: 0.8ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 34.7ms
# Speed: 0.7ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 39.7ms
# Speed: 0.7ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 35.9ms
# Speed: 0.7ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 38.4ms
# Speed: 0.9ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 42.7ms
# Speed: 0.8ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 34.8ms
# Speed: 0.8ms preprocess, 34.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 2 traffic_light_greens, 36.3ms
# Speed: 0.8ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 traffic_light_green, 37.1ms
# Speed: 0.8ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0 km/h
#
# 0: 384x640 (no detections), 36.9ms
# Speed: 0.8ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 0.15 km/h
#
# 0: 384x640 2 traffic_light_greens, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 0.51 km/h
#
# 0: 384x640 1 traffic_light_green, 36.7ms
# Speed: 0.9ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 1.15 km/h
#
# 0: 384x640 1 traffic_light_green, 37.9ms
# Speed: 0.9ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 1.41 km/h
#
# 0: 384x640 1 traffic_light_green, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 2.22 km/h
#
# 0: 384x640 2 traffic_light_greens, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 2.83 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 39.6ms
# Speed: 0.7ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 3.29 km/h
#
# 0: 384x640 1 traffic_light_green, 35.7ms
# Speed: 0.7ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 3.81 km/h
#
# 0: 384x640 1 traffic_light_yellow, 40.8ms
# Speed: 0.8ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 3.94 km/h
#
# 0: 384x640 1 traffic_light_green, 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 4.4 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 4.53 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 5.28 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 36.1ms
# Speed: 0.7ms preprocess, 36.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 5.43 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 4 traffic_light_yellows, 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 5.68 km/h
#
# 0: 384x640 1 traffic_light_green, 2 traffic_light_yellows, 41.7ms
# ...
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 6.71 km/h
#
# 0: 384x640 (no detections), 60.7ms
# Speed: 0.8ms preprocess, 60.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# No hay alerta.
# Velocidad actual: 7.02 km/h
#
# 0: 384x640 1 traffic_light_green, 47.4ms
# Speed: 0.8ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 7.6 km/h
#
# 0: 384x640 1 traffic_light_green, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 8.45 km/h
#
# 0: 384x640 1 traffic_light_green, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.09 km/h
#
# 0: 384x640 1 traffic_light_green, 89.3ms
# Speed: 1.1ms preprocess, 89.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 9.97 km/h
#
# 0: 384x640 1 traffic_light_green, 55.9ms
# Speed: 0.9ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 10.78 km/h
#
# 0: 384x640 1 traffic_light_green, 54.5ms
# Speed: 0.9ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 11.76 km/h
#
# 0: 384x640 1 traffic_light_green, 61.9ms
# Speed: 0.9ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 12.57 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 2 traffic_light_greens, 66.3ms
# Speed: 1.5ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 12.71 km/h
#
# 0: 384x640 1 traffic_light_green, 61.4ms
# Speed: 0.8ms preprocess, 61.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 12.89 km/h
#
# 0: 384x640 1 traffic_light_yellow, 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 13.24 km/h
#
# 0: 384x640 1 traffic_light_yellow, 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 13.98 km/h
#
# 0: 384x640 1 traffic_light_yellow, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 14.82 km/h
#
# 0: 384x640 1 traffic_light_yellow, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 15.77 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 77.4ms
# Speed: 1.0ms preprocess, 77.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 15.85 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 46.7ms
# Speed: 0.8ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 16.24 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 16.29 km/h
#
# 0: 384x640 1 traffic_light_green, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 16.51 km/h
#
# 0: 384x640 1 traffic_light_green, 46.5ms
# Speed: 0.9ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 16.6 km/h
#
# 0: 384x640 2 traffic_light_greens, 55.3ms
# Speed: 0.8ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 17.14 km/h
#
# 0: 384x640 1 traffic_light_green, 58.0ms
# Speed: 0.8ms preprocess, 58.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 18.02 km/h
#
# 0: 384x640 2 traffic_light_greens, 64.8ms
# Speed: 3.9ms preprocess, 64.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 18.64 km/h
#
# 0: 384x640 2 traffic_light_greens, 48.3ms
# Speed: 0.8ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.01 km/h
#
# 0: 384x640 1 traffic_light_green, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.68 km/h
#
# 0: 384x640 2 traffic_light_greens, 50.1ms
# Speed: 0.8ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 19.9 km/h
#
# 0: 384x640 1 traffic_light_green, 56.0ms
# Speed: 0.9ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 20.62 km/h
#
# 0: 384x640 2 traffic_light_greens, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 21.0 km/h
#
# 0: 384x640 2 traffic_light_greens, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 21.64 km/h
#
# 0: 384x640 2 traffic_light_greens, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 22.3 km/h
#
# 0: 384x640 3 traffic_light_greens, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 22.98 km/h
#
# 0: 384x640 3 traffic_light_greens, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 23.82 km/h
#
# 0: 384x640 4 traffic_light_greens, 52.4ms
# Speed: 1.3ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 24.45 km/h
#
# 0: 384x640 2 traffic_light_greens, 46.1ms
# Speed: 0.8ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 25.45 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 25.72 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 69.6ms
# Speed: 0.9ms preprocess, 69.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 26.06 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 26.76 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 27.4 km/h
#
# 0: 384x640 1 traffic_light_green, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 27.74 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 51.0ms
# Speed: 0.7ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 28.68 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_red, 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 29.65 km/h
#
# 0: 384x640 2 traffic_light_greens, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 29.88 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 30.87 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 44.7ms
# Speed: 0.9ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 31.84 km/h
#
# 0: 384x640 1 traffic_light_green, 43.0ms
# Speed: 0.8ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.06 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 53.4ms
# Speed: 0.9ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.31 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.59 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 32.88 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 33.49 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 48.8ms
# Speed: 2.1ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 33.56 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 48.6ms
# Speed: 0.7ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# No hay alerta.
# Velocidad actual: 34.5 km/h
#
# 0: 384x640 2 traffic_light_greens, 2 traffic_light_yellows, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# No hay alerta.
# Velocidad actual: 34.78 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 35.57 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 36.27 km/h
#
# 0: 384x640 2 traffic_light_yellows, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.11 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 39.2ms
# Speed: 0.9ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.22 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.59 km/h
#
# 0: 384x640 2 traffic_light_yellows, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.73 km/h
#
# 0: 384x640 2 traffic_light_yellows, 45.4ms
# Speed: 0.8ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.94 km/h
#
# 0: 384x640 2 traffic_light_yellows, 46.3ms
# Speed: 0.9ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 38.79 km/h
#
# 0: 384x640 2 traffic_light_yellows, 47.6ms
# Speed: 0.8ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 39.52 km/h
#
# 0: 384x640 2 traffic_light_yellows, 44.9ms
# Speed: 0.9ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 40.42 km/h
#
# 0: 384x640 2 traffic_light_yellows, 41.6ms
# Speed: 0.7ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 40.42 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 38.92 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 47.4ms
# Speed: 1.2ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 37.42 km/h
#
# 0: 384x640 1 traffic_light_yellow, 46.3ms
# Speed: 1.1ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 35.92 km/h
#
# 0: 384x640 2 traffic_light_yellows, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 34.42 km/h
#
# 0: 384x640 1 traffic_light_yellow, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 32.92 km/h
#
# 0: 384x640 1 traffic_light_yellow, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
# Velocidad actual: 31.42 km/h
#
# 0: 384x640 2 traffic_light_yellows, 44.8ms
# Speed: 0.9ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# No hay alerta.
