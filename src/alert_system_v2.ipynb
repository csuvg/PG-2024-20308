# %% [markdown]
# # Sistema de asistencia de manejo de un vehículo terrestre a través de visión por computadora V2

# %%
import time
import sys
import random
import cv2
import os
from datetime import datetime
from ultralytics import YOLO

# %% [markdown]
# Cargar las rutas de los otros modulos del sistema

# %%
# Cargar rutas
sys.path.append('sensores_input')
sys.path.append('Traffic_Signs_Model')

# %% [markdown]
# Cargar simulacion de sensores

# %%
from simulacionSensores import simulate_speed  # Importar simulador de velocidad

# %% [markdown]
# Cargar el modelo YOLOv8 entrenado

# %%
model = YOLO('Traffic_Signs_Model/traffic_signs_model.pt')

# %%
print(model.names)
# Out:
# {0: 'pedestrian_traffic_light_green', 1: 'pedestrian_traffic_light_red', 2: 'traffic_light_green', 3: 'traffic_light_red', 4: 'traffic_light_yellow', 5: 'stop'}

# %% [markdown]
# Definiciones generales de limites de velocidad y objetos peligrosos

# %%
SPEED_LIMIT = 80  # Límite de velocidad urbana (km/h)
DANGER_OBJECTS = ['stop', 'traffic_light_red', 'pedestrian_traffic_light_red']  # Objetos que generan alerta

# %% [markdown]
# Hacemos un archivo con logs para poder medir y saber como funciona nuestro modelo en su prueba en un entorno simulado

# %%
log_filename = 'modelv2_alert_log.txt'
with open(log_filename, 'w') as log_file:
    log_file.write("Alerta Log para ModelV2\n")
    log_file.write("Fecha de creación: " + datetime.now().strftime("%Y-%m-%d %H:%M:%S") + "\n\n")

# %% [markdown]
# Función para la generación de alertas

# %%
# Función para generar alertas detalladas
def generate_alert(object_detected, current_speed):
    if object_detected in DANGER_OBJECTS and current_speed > 0:
        if object_detected == 'stop':
            return f"ALERTA CRÍTICA: Deténgase inmediatamente. Objeto detectado: {object_detected} a {current_speed} km/h."
        if object_detected == 'traffic_light_red':
            return f"ALERTA: Semáforo en rojo detectado a {current_speed} km/h. Reduzca la velocidad y deténgase."
        if object_detected == 'pedestrian_traffic_light_red':
            return f"ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a {current_speed} km/h y esté preparado para detenerse."
    elif current_speed > SPEED_LIMIT:
        return f"Advertencia: Exceso de velocidad. Usted va a {current_speed} km/h en una zona con límite de {SPEED_LIMIT} km/h."
    else:
        return f"Velocidad adecuada: {current_speed} km/h. Continúe conduciendo con precaución."

# %% [markdown]
# Función para la detección de objetos frame a frame usando el modelo de YOLOv8

# %%
def detect_objects(frame):
    results = model(frame)
    if results and len(results[0].boxes) > 0:
        top_object_idx = int(results[0].boxes[0].cls.item())
        top_object = results[0].names[top_object_idx]
        return top_object
    return "No objects detected"

# %% [markdown]
# Procesar distintos tipos de input

# %%
def process_input(input_type, input_source, frame_rate=20):
    cap = None
    if input_type == 'image':
        # Cargar la imagen directamente
        frame = cv2.imread(input_source)
        yield frame, 0  # Se devuelve un timestamp de 0 ya que es una imagen estática

    elif input_type == 'video':
        cap = cv2.VideoCapture(input_source)

    elif input_type == 'camera':
        cap = cv2.VideoCapture(0)  # 0 para la cámara predeterminada

    # Si es un video o la cámara
    if cap:
        current_frame = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break  # Salir si no hay más frames o no se puede leer

            timestamp = cap.get(cv2.CAP_PROP_POS_MSEC)  # Obtener el timestamp en milisegundos

            if input_type == 'video' and current_frame % frame_rate == 0:
                yield frame, timestamp  # Devolver frame y timestamp cada 'frame_rate'

            elif input_type == 'camera':
                yield frame, timestamp  # Devolver frame en tiempo real si es la cámara

            current_frame += 1

        cap.release()

# %% [markdown]
# Funcionamiento del modelo en su versión 1

# %%
def modelv2(input_type='camera', input_source=None):
    # Inicializar parámetros de simulación de velocidad
    current_speed = 0
    max_speed = 70
    acceleration = 5.0
    deceleration = 7.0
    stop_deceleration = 15.0
    time_between_stops = 7
    stop_chance = 0.1

    # Iterar sobre los frames
    for frame, timestamp in process_input(input_type, input_source):
        # Simular velocidad
        current_speed = simulate_speed(current_speed, max_speed, acceleration, deceleration, stop_deceleration, time_between_stops, stop_chance)
        print(f"Velocidad actual: {current_speed} km/h")

        # Mostrar el frame en una ventana
        cv2.imshow("Frame", frame)

        # Procesar detección de objetos
        detected_object = detect_objects(frame)
        print(f"Objeto detectado: {detected_object}")

        # Generar alerta descriptiva
        alert_message = generate_alert(detected_object, current_speed)
        print(alert_message)

        # Guardar logs más detallados
        with open(log_filename, 'a') as log_file:
            log_file.write(f"Timestamp: {timestamp} ms\n")
            log_file.write(f"Velocidad: {current_speed} km/h\n")
            log_file.write(f"Objeto detectado: {detected_object}\n")
            log_file.write(f"Mensaje de alerta/información: {alert_message}\n")
            log_file.write(f"-----------------------------\n")

        # Guardar el frame donde se detecta la alerta
        if "ALERTA" in alert_message:
            alert_frame_name = f"alert_frames/frame_{timestamp}.jpg"
            if not os.path.exists("alert_frames"):
                os.makedirs("alert_frames")
            cv2.imwrite(alert_frame_name, frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        time.sleep(0.1)

    cv2.destroyAllWindows()

# %%
input_type = 'video'  # Cambiar entre 'image', 'video', 'camera' según sea necesario
input_source = 'video_input/Recorriendo CIUDAD DE GUATEMALA en vehículo (Parte 1) - GUATEMALA 2024.mp4'  # Ruta del archivo de video

# %%
modelv2(input_type, input_source)
# Out:
# Velocidad actual: 0.98 km/h
#
# 0: 384x640 2 traffic_light_yellows, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 0.98 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 1.55 km/h
#
# 0: 384x640 2 traffic_light_greens, 41.7ms
# Speed: 0.7ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 1.55 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 2.42 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 2.42 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 3.09 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 72.7ms
# Speed: 0.9ms preprocess, 72.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 3.09 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 4.01 km/h
#
# 0: 384x640 1 traffic_light_green, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 4.01 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 4.76 km/h
#
# 0: 384x640 1 traffic_light_green, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 4.76 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 4.86 km/h
#
# 0: 384x640 1 traffic_light_green, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 4.86 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 5.08 km/h
#
# 0: 384x640 2 traffic_light_greens, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 5.08 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 5.8 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 5.8 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 6.49 km/h
#
# 0: 384x640 3 traffic_light_greens, 42.8ms
# Speed: 0.7ms preprocess, 42.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 6.49 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 7.46 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 7.46 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 8.35 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 8.35 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 8.68 km/h
#
# 0: 384x640 2 traffic_light_greens, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 8.68 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 9.2 km/h
#
# 0: 384x640 1 traffic_light_green, 45.8ms
# Speed: 0.7ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 9.2 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 9.35 km/h
#
# 0: 384x640 3 traffic_light_greens, 54.3ms
# Speed: 0.9ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 9.35 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 10.25 km/h
#
# 0: 384x640 2 traffic_light_greens, 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 10.25 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 11.1 km/h
#
# 0: 384x640 1 traffic_light_green, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 11.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 11.42 km/h
#
# 0: 384x640 1 traffic_light_green, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 11.42 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 12.3 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 12.3 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 12.47 km/h
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 12.47 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 12.84 km/h
#
# 0: 384x640 1 traffic_light_green, 47.5ms
# Speed: 0.9ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 12.84 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 13.02 km/h
#
# 0: 384x640 1 traffic_light_green, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 13.02 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 13.34 km/h
#
# 0: 384x640 1 traffic_light_green, 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 13.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 13.36 km/h
#
# 0: 384x640 1 traffic_light_green, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 13.36 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 13.76 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 13.76 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 14.03 km/h
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 14.03 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 14.23 km/h
#
# 0: 384x640 2 traffic_light_greens, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 14.23 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 15.16 km/h
#
# 0: 384x640 2 traffic_light_greens, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 15.16 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 15.95 km/h
#
# 0: 384x640 2 traffic_light_greens, 44.0ms
# Speed: 0.7ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 15.95 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 16.33 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 16.33 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 17.16 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 43.3ms
# Speed: 0.8ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 17.16 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 17.43 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 17.43 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 18.14 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 18.14 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 18.78 km/h
#
# 0: 384x640 (no detections), 59.2ms
# Speed: 0.8ms preprocess, 59.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 18.78 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 19.77 km/h
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 0.7ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 19.77 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 20.54 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 45.0ms
# Speed: 0.9ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 20.54 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 21.2 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 21.2 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 21.35 km/h
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 0.7ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 21.35 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 22.21 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.6ms
# Speed: 0.8ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 22.21 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 23.06 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 23.06 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 23.61 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 1 stop, 45.5ms
# Speed: 0.8ms preprocess, 45.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 23.61 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 23.9 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 45.5ms
# Speed: 0.7ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 23.9 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 24.04 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 24.04 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 24.99 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 24.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 25.1 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 1 traffic_light_green, 43.1ms
# Speed: 0.7ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 25.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 25.31 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 58.9ms
# Speed: 0.8ms preprocess, 58.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 25.31 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 26.12 km/h
#
# 0: 384x640 1 traffic_light_green, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 26.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 26.35 km/h
#
# 0: 384x640 1 traffic_light_green, 38.0ms
# Speed: 0.7ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 26.35 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 26.85 km/h
#
# 0: 384x640 1 traffic_light_green, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 26.85 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 27.7 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 46.6ms
# Speed: 0.9ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: Semáforo en rojo detectado a 27.7 km/h. Reduzca la velocidad y deténgase.
# Velocidad actual: 28.4 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 50.0ms
# Speed: 0.8ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 28.4 km/h y esté preparado para detenerse.
# Velocidad actual: 28.85 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 28.85 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.53 km/h
#
# 0: 384x640 1 traffic_light_green, 50.3ms
# Speed: 0.9ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.53 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.09 km/h
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 30.09 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.06 km/h
#
# 0: 384x640 1 traffic_light_yellow, 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.06 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.94 km/h
#
# 0: 384x640 1 traffic_light_green, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.94 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.1 km/h
#
# 0: 384x640 2 traffic_light_greens, 44.1ms
# Speed: 0.7ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.58 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.58 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 1 traffic_light_green, 47.7ms
# Speed: 1.4ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.91 km/h
#
# 0: 384x640 1 traffic_light_green, 42.3ms
# Speed: 0.7ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.91 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.54 km/h
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.54 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.51 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.51 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.22 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.22 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.63 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 46.4ms
# Speed: 0.9ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 29.63 km/h y esté preparado para detenerse.
# Velocidad actual: 29.53 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.53 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.14 km/h
#
# 0: 384x640 2 traffic_light_greens, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.14 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 0.9ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 30.05 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.67 km/h
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.67 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.31 km/h
#
# 0: 384x640 1 traffic_light_green, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.31 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.45 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 3 traffic_light_greens, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.45 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.87 km/h
#
# 0: 384x640 1 traffic_light_green, 34.5ms
# Speed: 0.8ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.87 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.54 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.2ms
# Speed: 0.7ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.54 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.7 km/h
#
# 0: 384x640 1 traffic_light_green, 69.3ms
# Speed: 0.7ms preprocess, 69.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.7 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.06 km/h
#
# 0: 384x640 1 traffic_light_green, 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.06 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.64 km/h
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.64 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.91 km/h
#
# 0: 384x640 1 traffic_light_green, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.91 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.94 km/h
#
# 0: 384x640 1 traffic_light_green, 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.94 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.44 km/h
#
# 0: 384x640 2 traffic_light_greens, 39.8ms
# Speed: 0.9ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.44 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.54 km/h
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.54 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.01 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: Semáforo en rojo detectado a 30.01 km/h. Reduzca la velocidad y deténgase.
# Velocidad actual: 29.58 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 1 traffic_light_red, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: Semáforo en rojo detectado a 29.58 km/h. Reduzca la velocidad y deténgase.
# Velocidad actual: 30.25 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_red, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_red
# ALERTA: Semáforo en rojo detectado a 30.25 km/h. Reduzca la velocidad y deténgase.
# Velocidad actual: 30.22 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.22 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.21 km/h
#
# 0: 384x640 1 traffic_light_green, 44.8ms
# Speed: 0.9ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.21 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.75 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.8ms
# Speed: 0.9ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.75 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.82 km/h
#
# 0: 384x640 2 traffic_light_greens, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.82 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 1 traffic_light_green, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.27 km/h
#
# 0: 384x640 1 traffic_light_green, 42.5ms
# Speed: 0.8ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.27 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.07 km/h
#
# 0: 384x640 1 traffic_light_green, 43.3ms
# Speed: 0.7ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.07 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.59 km/h
#
# 0: 384x640 1 traffic_light_green, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.59 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.91 km/h
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 0.9ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.91 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.87 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 29.87 km/h y esté preparado para detenerse.
# Velocidad actual: 29.75 km/h
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 0.8ms preprocess, 52.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.75 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.86 km/h
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 0.8ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.86 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.44 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 1 traffic_light_green, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.44 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.79 km/h
#
# 0: 384x640 1 traffic_light_green, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.79 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.91 km/h
#
# 0: 384x640 2 traffic_light_greens, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.91 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.99 km/h
#
# 0: 384x640 2 traffic_light_greens, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.39 km/h
#
# 0: 384x640 1 traffic_light_green, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.39 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.17 km/h
#
# 0: 384x640 1 traffic_light_green, 42.3ms
# Speed: 0.6ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.17 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.2 km/h
#
# 0: 384x640 1 traffic_light_green, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.2 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.3 km/h
#
# 0: 384x640 1 traffic_light_green, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.3 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.31 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.31 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.64 km/h
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.8ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.64 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.47 km/h
#
# 0: 384x640 1 traffic_light_green, 45.8ms
# Speed: 0.6ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.47 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.46 km/h
#
# 0: 384x640 1 traffic_light_green, 47.7ms
# Speed: 0.9ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.46 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.89 km/h
#
# 0: 384x640 1 traffic_light_green, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.89 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.0 km/h
#
# 0: 384x640 1 traffic_light_green, 44.0ms
# Speed: 0.8ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.0 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.12 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 45.5ms
# Speed: 0.8ms preprocess, 45.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.59 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 54.8ms
# Speed: 0.8ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 29.59 km/h y esté preparado para detenerse.
# Velocidad actual: 29.96 km/h
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.96 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.3 km/h
#
# 0: 384x640 1 traffic_light_green, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.3 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 2 traffic_light_greens, 46.3ms
# Speed: 0.8ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.05 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.13 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 1 traffic_light_green, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 30.13 km/h y esté preparado para detenerse.
# Velocidad actual: 30.42 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 30.42 km/h y esté preparado para detenerse.
# Velocidad actual: 29.52 km/h
#
# 0: 384x640 1 traffic_light_green, 37.3ms
# Speed: 0.7ms preprocess, 37.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.52 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.9 km/h
#
# 0: 384x640 1 traffic_light_green, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.9 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.37 km/h
#
# 0: 384x640 1 traffic_light_green, 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.37 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.71 km/h
#
# 0: 384x640 2 traffic_light_yellows, 46.3ms
# Speed: 0.7ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.71 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.26 km/h
#
# 0: 384x640 1 traffic_light_yellow, 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.26 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.2 km/h
#
# 0: 384x640 2 traffic_light_yellows, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.2 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.76 km/h
#
# 0: 384x640 1 traffic_light_yellow, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.76 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 0.8ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.25 km/h
#
# 0: 384x640 1 traffic_light_green, 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.25 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.29 km/h
#
# 0: 384x640 1 traffic_light_green, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.29 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.32 km/h
#
# 0: 384x640 1 traffic_light_green, 41.6ms
# Speed: 0.8ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.32 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.12 km/h
#
# 0: 384x640 1 traffic_light_green, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.14 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 pedestrian_traffic_light_red, 44.7ms
# Speed: 0.8ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 30.14 km/h y esté preparado para detenerse.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.05 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.12 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.75 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 37.1ms
# Speed: 0.8ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.75 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.63 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.63 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.08 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.08 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.19 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 46.3ms
# Speed: 0.9ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.19 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.52 km/h
#
# 0: 384x640 3 pedestrian_traffic_light_greens, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.52 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.99 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.81 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.81 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.19 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 44.2ms
# Speed: 0.8ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.19 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.17 km/h
#
# 0: 384x640 1 stop, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: stop
# ALERTA CRÍTICA: Deténgase inmediatamente. Objeto detectado: stop a 30.17 km/h.
# Velocidad actual: 29.78 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.78 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.93 km/h
#
# 0: 384x640 2 pedestrian_traffic_light_greens, 1 traffic_light_green, 1 traffic_light_yellow, 62.8ms
# Speed: 0.9ms preprocess, 62.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.93 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.32 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 1 traffic_light_yellow, 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.32 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.71 km/h
#
# 0: 384x640 1 traffic_light_green, 43.1ms
# Speed: 0.7ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.71 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.61 km/h
#
# 0: 384x640 1 traffic_light_green, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.61 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.96 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 2 traffic_light_greens, 44.9ms
# Speed: 0.9ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.96 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 48.0ms
# Speed: 0.9ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.41 km/h
#
# 0: 384x640 1 traffic_light_green, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.41 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.33 km/h
#
# 0: 384x640 1 traffic_light_green, 41.1ms
# Speed: 0.8ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.33 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.92 km/h
#
# 0: 384x640 1 traffic_light_green, 43.7ms
# Speed: 0.8ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.92 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.68 km/h
#
# 0: 384x640 1 traffic_light_yellow, 42.9ms
# Speed: 0.6ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.68 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.93 km/h
#
# 0: 384x640 1 traffic_light_yellow, 46.4ms
# Speed: 0.9ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.93 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.71 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.71 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.68 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.68 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.06 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.06 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.28 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 3 traffic_light_greens, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.28 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.16 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_yellow, 45.2ms
# Speed: 0.8ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.16 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.34 km/h
#
# 0: 384x640 1 traffic_light_yellow, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.2 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 43.5ms
# Speed: 0.6ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.2 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.01 km/h
#
# 0: 384x640 1 traffic_light_green, 42.5ms
# Speed: 0.8ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.01 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.27 km/h
#
# 0: 384x640 1 traffic_light_green, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.27 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.99 km/h
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.12 km/h
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 30.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.32 km/h
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.7ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 30.32 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.95 km/h
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: No objects detected
# Velocidad adecuada: 29.95 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.58 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_red
# ALERTA: Semáforo peatonal rojo detectado. Reduzca la velocidad a 29.58 km/h y esté preparado para detenerse.
# Velocidad actual: 30.28 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_red, 41.9ms
# ...
#
# 0: 384x640 1 traffic_light_yellow, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.89 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.46 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 43.7ms
# Speed: 0.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.46 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.28 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.28 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.01 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 39.0ms
# Speed: 0.7ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.01 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.3 km/h
#
# 0: 384x640 1 traffic_light_green, 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.3 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.94 km/h
#
# 0: 384x640 1 traffic_light_green, 43.0ms
# Speed: 0.7ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.94 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.76 km/h
#
# 0: 384x640 2 traffic_light_greens, 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.76 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.13 km/h
#
# 0: 384x640 1 traffic_light_green, 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.13 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.0 km/h
#
# 0: 384x640 2 traffic_light_greens, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.0 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.85 km/h
#
# 0: 384x640 2 traffic_light_greens, 51.7ms
# Speed: 0.9ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.85 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.96 km/h
#
# 0: 384x640 1 traffic_light_green, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.96 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.77 km/h
#
# 0: 384x640 2 traffic_light_greens, 71.5ms
# Speed: 0.9ms preprocess, 71.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.77 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.4 km/h
#
# 0: 384x640 1 traffic_light_green, 45.3ms
# Speed: 0.8ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.4 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.79 km/h
#
# 0: 384x640 2 traffic_light_greens, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.79 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.65 km/h
#
# 0: 384x640 2 traffic_light_greens, 52.1ms
# Speed: 0.9ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.65 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.63 km/h
#
# 0: 384x640 2 traffic_light_greens, 52.2ms
# Speed: 0.9ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.63 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.44 km/h
#
# 0: 384x640 3 traffic_light_greens, 46.4ms
# Speed: 0.9ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.44 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.16 km/h
#
# 0: 384x640 3 traffic_light_greens, 53.6ms
# Speed: 0.8ms preprocess, 53.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.16 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 4 traffic_light_greens, 46.3ms
# Speed: 0.8ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.05 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.1 km/h
#
# 0: 384x640 2 traffic_light_greens, 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.93 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.93 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.27 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 30.27 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.99 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 44.2ms
# Speed: 0.7ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.75 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 72.4ms
# Speed: 0.8ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.75 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.53 km/h
#
# 0: 384x640 1 traffic_light_green, 45.0ms
# Speed: 0.8ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.53 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.24 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_red, 45.3ms
# Speed: 0.8ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.24 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.12 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_red, 45.2ms
# Speed: 0.9ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.12 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.46 km/h
#
# 0: 384x640 2 traffic_light_greens, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.46 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.32 km/h
#
# 0: 384x640 2 traffic_light_greens, 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.32 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.79 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 42.9ms
# Speed: 0.9ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 29.79 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.05 km/h
#
# 0: 384x640 1 traffic_light_green, 46.2ms
# Speed: 0.8ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.05 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.14 km/h
#
# 0: 384x640 2 traffic_light_greens, 1 traffic_light_yellow, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.14 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.39 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.39 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.34 km/h
#
# 0: 384x640 2 traffic_light_greens, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.48 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 43.7ms
# Speed: 0.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.48 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.99 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 51.1ms
# Speed: 0.9ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.99 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.67 km/h
#
# 0: 384x640 1 pedestrian_traffic_light_green, 1 traffic_light_green, 47.5ms
# Speed: 0.8ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: pedestrian_traffic_light_green
# Velocidad adecuada: 29.67 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.1 km/h
#
# 0: 384x640 2 traffic_light_greens, 2 traffic_light_yellows, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_green
# Velocidad adecuada: 30.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.9 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.9 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.23 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.23 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.32 km/h
#
# 0: 384x640 2 traffic_light_yellows, 38.8ms
# Speed: 0.8ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.32 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.63 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 55.2ms
# Speed: 0.8ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.63 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.33 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 54.0ms
# Speed: 0.9ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.33 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.1 km/h
#
# 0: 384x640 2 traffic_light_yellows, 42.0ms
# Speed: 0.9ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.1 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.43 km/h
#
# 0: 384x640 2 traffic_light_yellows, 48.6ms
# Speed: 0.8ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.43 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.55 km/h
#
# 0: 384x640 2 traffic_light_yellows, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.55 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.73 km/h
#
# 0: 384x640 2 traffic_light_yellows, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.73 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.36 km/h
#
# 0: 384x640 2 traffic_light_yellows, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.36 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.42 km/h
#
# 0: 384x640 2 traffic_light_yellows, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.42 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.7 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.7 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 29.83 km/h
#
# 0: 384x640 1 traffic_light_green, 1 traffic_light_yellow, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 29.83 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.34 km/h
#
# 0: 384x640 1 traffic_light_yellow, 44.9ms
# Speed: 0.9ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.34 km/h
#
# 0: 384x640 2 traffic_light_yellows, 72.6ms
# Speed: 1.2ms preprocess, 72.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.21 km/h
#
# 0: 384x640 1 traffic_light_yellow, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.21 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.34 km/h
#
# 0: 384x640 1 traffic_light_yellow, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.34 km/h. Continúe conduciendo con precaución.
# Velocidad actual: 30.1 km/h
#
# 0: 384x640 2 traffic_light_yellows, 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Objeto detectado: traffic_light_yellow
# Velocidad adecuada: 30.1 km/h. Continúe conduciendo con precaución.
